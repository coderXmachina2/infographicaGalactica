# %%
#now for loop that sum bitch
#scrape SDO images. Take that system

import requests
import urllib.request
import time
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

#pd.set_option('display.max_colwidth', -1)
#pd.options.display.max_colwidth
import datetime

theTime = datetime.datetime(2013, 2, 22, 6,  0, 10) #year month day hour, minute, second #this one chooses the date

index0 = 2
index1 = 24

tReq = str(format(theTime.hour, '02')) + str(format(theTime.minute, '02')) + str(format(theTime.second, '02'))
downloadString = "https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/22/20130222_" + tReq + "_1024_0171.jpg"

#start iteration
for l in range(0,94): #download one day
    
    for p in range(0,140): #cycle through these seconds for a possible new image download
        #make new downloadString
        theTime =  theTime + datetime.timedelta(0,1) #start increment
        tReq = str(format(theTime.hour, '02')) + str(format(theTime.minute, '02')) + str(format(theTime.second, '02'))
        downloadString = "https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/22/20130222_" + tReq + "_1024_0171.jpg"
        
        request = requests.get(downloadString)
        if request.status_code == 200:
            print('Image at ' + tReq +  ' exists... Downloading.')
            folderString = "praiseTheSun/" + str(index0) + str(index1) + ".jpg"
            myImage = urllib.request.urlretrieve(downloadString, folderString) #download successful
            print("Downloaded image " + str(index0) + str(index1) + "\n")
            index1 = index1 + 1
            theTime  = theTime + datetime.timedelta(0,800) #minimum jump 13 minutes 30 seconds
            
            break;

        else:
            print(str(p) + " Image at " + tReq + " does not exist. Increment")
# Out:
# 0 Image at 060011 does not exist. Increment
# Image at 060012 exists... Downloading.
# Downloaded image 224
#
# 0 Image at 061333 does not exist. Increment
# 1 Image at 061334 does not exist. Increment
# 2 Image at 061335 does not exist. Increment
# 3 Image at 061336 does not exist. Increment
# 4 Image at 061337 does not exist. Increment
# 5 Image at 061338 does not exist. Increment
# 6 Image at 061339 does not exist. Increment
# 7 Image at 061340 does not exist. Increment
# 8 Image at 061341 does not exist. Increment
# 9 Image at 061342 does not exist. Increment
# 10 Image at 061343 does not exist. Increment
# 11 Image at 061344 does not exist. Increment
# 12 Image at 061345 does not exist. Increment
# 13 Image at 061346 does not exist. Increment
# 14 Image at 061347 does not exist. Increment
# 15 Image at 061348 does not exist. Increment
# 16 Image at 061349 does not exist. Increment
# 17 Image at 061350 does not exist. Increment
# 18 Image at 061351 does not exist. Increment
# 19 Image at 061352 does not exist. Increment
# 20 Image at 061353 does not exist. Increment
# 21 Image at 061354 does not exist. Increment
# 22 Image at 061355 does not exist. Increment
# 23 Image at 061356 does not exist. Increment
# 24 Image at 061357 does not exist. Increment
# 25 Image at 061358 does not exist. Increment
# 26 Image at 061359 does not exist. Increment
# 27 Image at 061400 does not exist. Increment
# 28 Image at 061401 does not exist. Increment
# 29 Image at 061402 does not exist. Increment
# 30 Image at 061403 does not exist. Increment
# 31 Image at 061404 does not exist. Increment
# 32 Image at 061405 does not exist. Increment
# 33 Image at 061406 does not exist. Increment
# 34 Image at 061407 does not exist. Increment
# 35 Image at 061408 does not exist. Increment
# 36 Image at 061409 does not exist. Increment
# 37 Image at 061410 does not exist. Increment
# 38 Image at 061411 does not exist. Increment
# 39 Image at 061412 does not exist. Increment
# 40 Image at 061413 does not exist. Increment
# 41 Image at 061414 does not exist. Increment
# 42 Image at 061415 does not exist. Increment
# 43 Image at 061416 does not exist. Increment
# 44 Image at 061417 does not exist. Increment
# 45 Image at 061418 does not exist. Increment
# 46 Image at 061419 does not exist. Increment
# 47 Image at 061420 does not exist. Increment
# 48 Image at 061421 does not exist. Increment
# 49 Image at 061422 does not exist. Increment
# 50 Image at 061423 does not exist. Increment
# 51 Image at 061424 does not exist. Increment
# 52 Image at 061425 does not exist. Increment
# 53 Image at 061426 does not exist. Increment
# 54 Image at 061427 does not exist. Increment
# 55 Image at 061428 does not exist. Increment
# 56 Image at 061429 does not exist. Increment
# 57 Image at 061430 does not exist. Increment
# 58 Image at 061431 does not exist. Increment
# 59 Image at 061432 does not exist. Increment
# 60 Image at 061433 does not exist. Increment
# 61 Image at 061434 does not exist. Increment
# 62 Image at 061435 does not exist. Increment
# 63 Image at 061436 does not exist. Increment
# 64 Image at 061437 does not exist. Increment
# 65 Image at 061438 does not exist. Increment
# 66 Image at 061439 does not exist. Increment
# 67 Image at 061440 does not exist. Increment
# 68 Image at 061441 does not exist. Increment
# 69 Image at 061442 does not exist. Increment
# 70 Image at 061443 does not exist. Increment
# 71 Image at 061444 does not exist. Increment
# 72 Image at 061445 does not exist. Increment
# 73 Image at 061446 does not exist. Increment
# 74 Image at 061447 does not exist. Increment
# 75 Image at 061448 does not exist. Increment
# 76 Image at 061449 does not exist. Increment
# 77 Image at 061450 does not exist. Increment
# 78 Image at 061451 does not exist. Increment
# 79 Image at 061452 does not exist. Increment
# 80 Image at 061453 does not exist. Increment
# 81 Image at 061454 does not exist. Increment
# 82 Image at 061455 does not exist. Increment
# 83 Image at 061456 does not exist. Increment
# 84 Image at 061457 does not exist. Increment
# 85 Image at 061458 does not exist. Increment
# 86 Image at 061459 does not exist. Increment
# Image at 061500 exists... Downloading.
# Downloaded image 225
#
# 0 Image at 062821 does not exist. Increment
# 1 Image at 062822 does not exist. Increment
# 2 Image at 062823 does not exist. Increment
# 3 Image at 062824 does not exist. Increment
# 4 Image at 062825 does not exist. Increment
# 5 Image at 062826 does not exist. Increment
# 6 Image at 062827 does not exist. Increment
# 7 Image at 062828 does not exist. Increment
# 8 Image at 062829 does not exist. Increment
# 9 Image at 062830 does not exist. Increment
# 10 Image at 062831 does not exist. Increment
# 11 Image at 062832 does not exist. Increment
# 12 Image at 062833 does not exist. Increment
# 13 Image at 062834 does not exist. Increment
# 14 Image at 062835 does not exist. Increment
# 15 Image at 062836 does not exist. Increment
# 16 Image at 062837 does not exist. Increment
# 17 Image at 062838 does not exist. Increment
# 18 Image at 062839 does not exist. Increment
# 19 Image at 062840 does not exist. Increment
# 20 Image at 062841 does not exist. Increment
# 21 Image at 062842 does not exist. Increment
# 22 Image at 062843 does not exist. Increment
# 23 Image at 062844 does not exist. Increment
# 24 Image at 062845 does not exist. Increment
# 25 Image at 062846 does not exist. Increment
# 26 Image at 062847 does not exist. Increment
# 27 Image at 062848 does not exist. Increment
# 28 Image at 062849 does not exist. Increment
# 29 Image at 062850 does not exist. Increment
# 30 Image at 062851 does not exist. Increment
# 31 Image at 062852 does not exist. Increment
# 32 Image at 062853 does not exist. Increment
# 33 Image at 062854 does not exist. Increment
# 34 Image at 062855 does not exist. Increment
# 35 Image at 062856 does not exist. Increment
# 36 Image at 062857 does not exist. Increment
# 37 Image at 062858 does not exist. Increment
# 38 Image at 062859 does not exist. Increment
# 39 Image at 062900 does not exist. Increment
# 40 Image at 062901 does not exist. Increment
# 41 Image at 062902 does not exist. Increment
# 42 Image at 062903 does not exist. Increment
# 43 Image at 062904 does not exist. Increment
# 44 Image at 062905 does not exist. Increment
# 45 Image at 062906 does not exist. Increment
# 46 Image at 062907 does not exist. Increment
# 47 Image at 062908 does not exist. Increment
# 48 Image at 062909 does not exist. Increment
# 49 Image at 062910 does not exist. Increment
# 50 Image at 062911 does not exist. Increment
# 51 Image at 062912 does not exist. Increment
# 52 Image at 062913 does not exist. Increment
# 53 Image at 062914 does not exist. Increment
# 54 Image at 062915 does not exist. Increment
# 55 Image at 062916 does not exist. Increment
# 56 Image at 062917 does not exist. Increment
# 57 Image at 062918 does not exist. Increment
# 58 Image at 062919 does not exist. Increment
# 59 Image at 062920 does not exist. Increment
# 60 Image at 062921 does not exist. Increment
# 61 Image at 062922 does not exist. Increment
# 62 Image at 062923 does not exist. Increment
# 63 Image at 062924 does not exist. Increment
# 64 Image at 062925 does not exist. Increment
# 65 Image at 062926 does not exist. Increment
# 66 Image at 062927 does not exist. Increment
# 67 Image at 062928 does not exist. Increment
# 68 Image at 062929 does not exist. Increment
# 69 Image at 062930 does not exist. Increment
# 70 Image at 062931 does not exist. Increment
# 71 Image at 062932 does not exist. Increment
# 72 Image at 062933 does not exist. Increment
# 73 Image at 062934 does not exist. Increment
# 74 Image at 062935 does not exist. Increment
# 75 Image at 062936 does not exist. Increment
# 76 Image at 062937 does not exist. Increment
# 77 Image at 062938 does not exist. Increment
# 78 Image at 062939 does not exist. Increment
# 79 Image at 062940 does not exist. Increment
# 80 Image at 062941 does not exist. Increment
# 81 Image at 062942 does not exist. Increment
# 82 Image at 062943 does not exist. Increment
# 83 Image at 062944 does not exist. Increment
# 84 Image at 062945 does not exist. Increment
# 85 Image at 062946 does not exist. Increment
# 86 Image at 062947 does not exist. Increment
# Image at 062948 exists... Downloading.
# Downloaded image 226
#
# 0 Image at 064309 does not exist. Increment
# 1 Image at 064310 does not exist. Increment
