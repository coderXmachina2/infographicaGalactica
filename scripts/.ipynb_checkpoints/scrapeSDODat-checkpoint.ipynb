# %%
#scrape SDO images. Take that system

import requests
import urllib.request
import time
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

#pd.set_option('display.max_colwidth', -1)
#pd.options.display.max_colwidth

# %%
index0 = 0
index1 = 0

#lowest limit = 000012
#highest limit = 234500

nasaArchive = 12 #string formatting

downloadString = "https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_" + format(nasaArchive, '06') + "_1024_0171.jpg"
folderString = "praiseTheSun/" + str(index0) + str(index1) + ".jpg"

myImage = urllib.request.urlretrieve(downloadString, folderString)

# %%
index0 = 0
index1 = 0

#lowest limit = 000012
#highest limit = 234500

#this is impractical. Try again Bragg.

for t in range(0,234500): #cycle all, just make sure its 6 integer string
    downloadString = "https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_" + format(t, '06') + "_1024_0171.jpg"
    print("attempting to download image: " + downloadString)
    request = requests.get(downloadString)
    if request.status_code == 200:
        print('Image exists... Downloading.')
        folderString = "praiseTheSun/" + str(index0) + str(index1) + ".jpg"
        myImage = urllib.request.urlretrieve(downloadString, folderString) #make request
        print("downloaded image" + str(index0) + str(index1))
        index1 = index1 + 1
    else:
        print('Image does not exist')
# Out:
# attempting to download image: https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_000000_1024_0171.jpg
# Image does not exist
# attempting to download image: https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_000001_1024_0171.jpg
# Image does not exist
# attempting to download image: https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_000002_1024_0171.jpg
# Image does not exist
# attempting to download image: https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_000003_1024_0171.jpg
# Image does not exist
# attempting to download image: https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_000004_1024_0171.jpg
# Image does not exist
# attempting to download image: https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_000005_1024_0171.jpg
# Image does not exist
# attempting to download image: https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_000006_1024_0171.jpg
# Image does not exist
# ...

# %%
#print (str(a.time()) + " hh:mm:ss")
#print (str(b.time()) + " hh:mm:ss")

#print("\n")

#with this you can download 
#print(format(a.hour, '02'))
#print(format(a.minute, '02'))
#print(format(a.second, '02'))

#print("\n")

#print(format(b.hour, '02'))
#print(format(b.minute, '02'))
#print(format(b.second, '02'))

# %%
#play with python time library

import datetime

#15 minutes is 900 seconds
#13 minutes 30 secodns = 810 seconds

index0 = 0
index1 = 0

#initialize at 000012
a = datetime.datetime(2013, 1, 21, 0, 0, 12) #initialize
b = a + datetime.timedelta(0,936) # jump
c = b + datetime.timedelta(0,888) # jump

timeString1 = str(  format(a.hour, '02')) + str(format(a.minute, '02')) + str(format(a.second, '02'))

downloadString1 = "https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_" + timeString1 + "_1024_0171.jpg"
folderString = "praiseTheSun/" + str(index0) + str(index1) + ".jpg"

print(downloadString01)
myImage = urllib.request.urlretrieve(downloadString1, folderString)

index1 = index1 + 1

timeString2 = str(format(b.hour, '02')) + str(format(b.minute, '02')) + str(format(b.second, '02'))
downloadString2 = "https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_" + timeString2 + "_1024_0171.jpg"
folderString = "praiseTheSun/" + str(index0) + str(index1) + ".jpg"

print(downloadString2)
myImage = urllib.request.urlretrieve(downloadString2, folderString)

index1 = index1 + 1

timeString3 = str(format(c.hour, '02')) + str(format(c.minute, '02')) + str(format(c.second, '02'))
downloadString3 = "https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_" + timeString3 + "_1024_0171.jpg"
folderString = "praiseTheSun/" + str(index0) + str(index1) + ".jpg"

print(downloadString2)
myImage = urllib.request.urlretrieve(downloadString3, folderString)
# Out:
# https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_001548_1024_0171.jpg
# https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_001548_1024_0171.jpg
# https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_001548_1024_0171.jpg

# %%
#now for loop that sum bitch

import datetime

theTime = datetime.datetime(2013, 2, 21, 9, 30, 10) #year month day hour, minute, second #this one chooses the date

index0 = 0
index1 = 38

tReq = str(format(theTime.hour, '02')) + str(format(theTime.minute, '02')) + str(format(theTime.second, '02'))
downloadString = "https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_" + tReq + "_1024_0171.jpg"

#start iteration
for l in range(0,94): #download one day
    
    for p in range(0,140): #cycle through these seconds for a possible new image download
        #make new downloadString
        theTime =  theTime + datetime.timedelta(0,1) #start increment
        tReq = str(format(theTime.hour, '02')) + str(format(theTime.minute, '02')) + str(format(theTime.second, '02'))
        downloadString = "https://sdo.gsfc.nasa.gov/assets/img/browse/2013/02/21/20130221_" + tReq + "_1024_0171.jpg"
        
        request = requests.get(downloadString)
        if request.status_code == 200:
            print('Image at ' + tReq +  ' exists... Downloading.')
            folderString = "praiseTheSun/" + str(index0) + str(index1) + ".jpg"
            myImage = urllib.request.urlretrieve(downloadString, folderString) #download successful
            print("Downloaded image " + str(index0) + str(index1) + "\n")
            index1 = index1 + 1
            theTime  = theTime + datetime.timedelta(0,800) #minimum jump 13 minutes 30 seconds
            
            break;

        else:
            print(str(p) + " Image at " + tReq + " does not exist. Increment")
# Out:
# 0 Image at 093011 does not exist. Increment
# Image at 093012 exists... Downloading.
# Downloaded image 038
#
# 0 Image at 094333 does not exist. Increment
# 1 Image at 094334 does not exist. Increment
# 2 Image at 094335 does not exist. Increment
# 3 Image at 094336 does not exist. Increment
# 4 Image at 094337 does not exist. Increment
# 5 Image at 094338 does not exist. Increment
# 6 Image at 094339 does not exist. Increment
# 7 Image at 094340 does not exist. Increment
# 8 Image at 094341 does not exist. Increment
# 9 Image at 094342 does not exist. Increment
# 10 Image at 094343 does not exist. Increment
# 11 Image at 094344 does not exist. Increment
# 12 Image at 094345 does not exist. Increment
# 13 Image at 094346 does not exist. Increment
# 14 Image at 094347 does not exist. Increment
# 15 Image at 094348 does not exist. Increment
# 16 Image at 094349 does not exist. Increment
# 17 Image at 094350 does not exist. Increment
# 18 Image at 094351 does not exist. Increment
# ...

# %%
print(str(theTime))
