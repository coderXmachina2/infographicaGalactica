# %%
#scrape nasa exo tables NICE NICE!

import requests
import urllib.request
import time
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

pd.set_option('display.max_colwidth', -1)
pd.options.display.max_colwidth
# Out:
# -1

# %%
url = "https://exoplanetarchive.ipac.caltech.edu/docs/API_exoplanet_columns.html"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
pageHeaders = soup.findAll('h2' )
allTables = soup.findAll('table' )

print("Number of headers: " + str(len(pageHeaders)))
print("Number of tables: " + str(len(allTables)))
# Out:
# Number of headers: 5
# Number of tables: 5

# %%
#extract Tables
tables = [
    [
        [td.get_text(strip=True) for td in tr.find_all('td')] 
        for tr in table.find_all('tr')
    ] 
    for table in allTables
]

# %%
paramCount = 0
for i in range (0, len(tables)):
    paramCount = paramCount + len(tables[i])
    print(pageHeaders[i].text + " " +  str(len(tables[i])) + " parameters")
    
print("\nTotal number of parameter describing exoplanets = " + str(paramCount) + "\n")

print(len(dfDef))
print(len(dfPl))
print(len(dfSt))
print(len(dfPho))
print(len(dfClr))
# Out:
# Default Columns 33 parameters
# Planet Columns 41 parameters
# Stellar  Columns 36 parameters
# Photometry Columns 25 parameters
# Color Columns 12 parameters
#
# Total number of parameter describing exoplanets = 147
#
# 32
# 40
# 35
# 24
# 11

# %%
#these were missing
tables[0][0] = 'Database Column Name','Table Label','Description', 'Uncertainties Column (positive +) (negative -)', 'Displayed String Name','Limit Column','Number of Measurements'
tables[1][0] = 'Database Column Name','Table Label','Description', 'Uncertainties Column (positive +) (negative -)', 'Displayed String Name','Limit Column','Number of Measurements'
tables[2][0] = 'Database Column Name','Table Label','Description', 'Uncertainties Column (positive +) (negative -)', 'Displayed String Name','Limit Column','Number of Measurements'
tables[3][0] = 'Database Column Name','Table Label','Description', 'Uncertainties Column (positive +) (negative -)', 'Displayed String Name','Limit Column','Number of Measurements'
tables[4][0] = 'Database Column Name','Table Label','Description', 'Uncertainties Column (positive +) (negative -)', 'Displayed String Name','Limit Column','Number of Measurements'

print(tables[0][0])
print(tables[1][0])
print(tables[2][0])
print(tables[3][0])
print(tables[4][0])
# Out:
# ('Database Column Name', 'Table Label', 'Description', 'Uncertainties Column (positive +) (negative -)', 'Displayed String Name', 'Limit Column', 'Number of Measurements')
# ('Database Column Name', 'Table Label', 'Description', 'Uncertainties Column (positive +) (negative -)', 'Displayed String Name', 'Limit Column', 'Number of Measurements')
# ('Database Column Name', 'Table Label', 'Description', 'Uncertainties Column (positive +) (negative -)', 'Displayed String Name', 'Limit Column', 'Number of Measurements')
# ('Database Column Name', 'Table Label', 'Description', 'Uncertainties Column (positive +) (negative -)', 'Displayed String Name', 'Limit Column', 'Number of Measurements')
# ('Database Column Name', 'Table Label', 'Description', 'Uncertainties Column (positive +) (negative -)', 'Displayed String Name', 'Limit Column', 'Number of Measurements')

# %%
#reconstruct table
#table 0  item 1 column
a = tables[0][1][0].encode('ascii', 'ignore').decode('ascii')
print(a)
print(tables[0][1][1])
print(tables[0][1][2])
# Out:
# pl_hostname
# Host Star Name
# Stellar name most commonly used in the literature.

# %%
len(tables[0])
# Out:
# 33

# %%
df = pd.DataFrame(columns=["Database Column Name", "Table Label", "Description"])
df
# Out:
# Empty DataFrame
# Columns: [Database Column Name, Table Label, Description]
# Index: []

# %%
#here is one example of how to do it. didn't turn up too well to spec

countUp = 0
for t in range(0,len(tables)):
    for p in range(1, len(tables[t])):
        df.loc[countUp] = [tables[t][p][0].encode('ascii', 'ignore').decode('ascii')] + [tables[t][p][1]] + [tables[t][p][2].replace("\n", " ")]
        countUp += 1
        if(p == len(tables[t]) - 1): #end of table
            df.loc[countUp+1] = [" "] + [" "] + [" "] #
            countUp += 1

#this seems fairly accurate
export_csv = df.to_csv (r'C:\Users\afiqAUT\Documents\projectRepos\infographicaRepo\infographicaGalactica\export_dataframe.csv', index = None, header=True)

# %%
df
# Out:
#     Database Column Name                             Table Label  \
# 0    pl_hostname          Host Star Name
# 1    pl_letter            Planet Letter
# 2    pl_name              Planet Name
# 3    pl_discmethod        Discovery Method
# 4    pl_controvflag       Controversial Flag
# 5    pl_pnum              Number of Planets in System
# 6    pl_orbper            Orbital Period (days)
# 7    pl_orbsmax           Orbit Semi-Major Axis (AU)
# 8    pl_orbeccen          Eccentricity
# 9    pl_orbincl           Inclination (deg)
# 10   pl_bmassj            Planet Mass or M*sin(i) [Jupiter mass]
# 11   pl_bmassprov         Planet Mass or M*sin(i) Provenance
# 12   pl_radj              Planet Radius (Jupiter radii)
# 13   pl_dens              Planet Density (g/cm**3)
# 14   pl_ttvflag           TTV Flag
# 15   pl_kepflag           Kepler Field Flag
# 16   pl_k2flag            K2 Mission Flag
# 17   pl_nnotes            Number of Notes
# 18   ra_str               RA (sexagesimal)
# 19   dec_str              Dec (sexagesimal)
# 20   ra                   RA (decimal degrees)
# 21   dec                  Dec (decimal degrees)
# 22   st_dist              Distance (pc)
# 23   gaia_dist            GaiaDistance [pc]
# 24   st_optmag            Optical Magnitude [mag]
# 25   st_optband           Optical Magnitude Band
# 26   gaia_gmag            G-band (Gaia) [mag]
# 27   st_teff              Effective  Temperature (K)
# 28   st_mass              Stellar Mass (solar mass)
# 29   st_rad               Stellar Radius (solar radii)
# ..      ...                                        ...
# 116  st_h                 H-band (2MASS) [mag]
# 117  st_k                 Ks-band (2MASS) [mag]
# 118  st_wise1             WISE 3.4um [mag]
# 119  st_wise2             WISE 4.6um [mag]
# 120  st_wise3             WISE 12.um [mag]
# 121  st_wise4             WISE 22.um [mag]
# 122  st_irac1             IRAC 3.6um [mag]
# 123  st_irac2             IRAC 4.5um [mag]
# 124  st_irac3             IRAC 5.8um [mag]
# 125  st_irac4             IRAC 8.0um [mag]
# 126  st_mips1             MIPS 24um [mag]
# 127  st_mips2             MIPS 70um [mag]
# 128  st_mips3             MIPS 160um [mag]
# 129  st_iras1             IRAS 12um [Jy]
# 130  st_iras2             IRAS 25um [Jy]
# 131  st_iras3             IRAS 60um [Jy]
# 132  st_iras4             IRAS 100um [Jy]
# 133  st_photn             Number of Photometry Measurements
# 135  st_umbj              U-B (Johnson) [mag]
# 136  st_bmvj              B-V (Johnson) [mag]
# 137  st_vjmic             V-I (Johnson-Cousins) [mag]
# 138  st_vjmrc             V-R (Johnson-Cousins) [mag]
# 139  st_jmh2              J-H (2MASS) [mag]
# 140  st_hmk2              H-Ks (2MASS) [mag]
# 141  st_jmk2              J-Ks  (2MASS) [mag]
# 142  st_bmy               b-y (Stromgren) [mag]
# 143  st_m1                m1 (Stromgren) [mag]
# 144  st_c1                c1 (Stromgren) [mag]
# 145  st_colorn            Number of Color Measurements
# 147
#
#                                                                                                                                                                                                                                                                                                            Description
# 0    Stellar name most commonly used in the literature.
# 1    Letter assigned to the planetary component of a planetary system.
# 2    Planet name most commonly used in the literature.
# 3    Method by which the planet was first identified.
# 4    Flag indicating whether the confirmation status of a planet  has been questioned in the published literature (1=yes, 0=no)
# 5    Number of planets in the planetary system.
# 6    Time the planet takes to make a complete  orbit around the host star or system.
# 7    The longest radius of an elliptic orbit,  or, for exoplanets detected via gravitational microlensing or direct imaging, the projected  separation in the plane of the sky.
# 8    Amount by which the orbit of the planet  deviates from a perfect circle.
# 9    Angular distance of the orbital plane from the line of sight.
# 10   Best planet mass estimate available, in order of preference:  Mass, M*sin(i)/sin(i), or M*sin(i), depending on availability,  and measured in Jupiter masses. See Planet Mass M*sin(i)  Provenance (pl_bmassprov) to determine which measure applies.
# 11   Provenance of the measurement of the best mass.  Options are: Mass, M*sin(i)/sin(i), and M*sini.
# 12   Length of a line segment from the center of the planet  to its surface, measured in units of radius of Jupiter.
# 13   Amount of mass per unit of volume of the planet.
# 14   Flag indicating if the planet orbit exhibits  transit timing variations from another planet in the system (1=yes, 0=no).Note:Non-transiting planets discovered via the transit timing variations of another planet in the system will not have their TTV flag set, since they do not themselves demonstrate TTVs.
# 15   Flag indicating if the planetary system  signature is present in data taken with  the Kepler mission (1=yes, 0=no).
# 16   Flag indicating if the planetary system  signature is present in data taken with  the K2 Mission (1=yes, 0=no).
# 17   Number of Notes associated with the planet.  View all notes in the Confirmed Planet Overview page.
# 18   Right Ascension of the planetary system in sexagesimal format.
# 19   Declination of the planetary system in sexagesimal notation.
# 20   Right Ascension of the planetary system in decimal degrees.
# 21   Declination of the planetary system in decimal degrees.
# 22   Distance to the planetary system in units of parsecs.
# 23   Distance computed fromGaiaparallax.
# 24   Brightness of the host star as measured using  the V (Johnson) or the Kepler-band in units of  magnitudes.
# 25   Band corresponding to the Optical Magnitude.  Options are: V (Johnson) or Kepler-band.
# 26   Brightness of the host star as measuring using  theGaiaband in units of magnitudes. Objects matched toGaiausing the Hipparcos or 2MASS IDs provided inGaiaDR2.
# 27   Temperature of the star as modeled by a  black body emitting the same total amount  of electromagnetic radiation.
# 28   Amount of matter contained in the star,  measured in units of masses of the Sun.
# 29   Length of a line segment from the center of the star  to its surface, measured in units of radius of the Sun.
# ..                                                                                                             ...
# 116  Brightness of the host star as measured using the  H (2MASS) band in units of magnitudes.
# 117  Brightness of the host star as measured using the  K (2MASS) band in units of magnitudes.
# 118  Brightness of the host star as measured using the 3.4um (WISE) band in units of magnitudes.
# 119  Brightness of the host star as measured using the 4.6um (WISE) band in units of magnitudes.
# 120  Brightness of the host star as measured using the 12.um (WISE) band in units of magnitudes.
# 121  Brightness of the host star as measured using the 22.um (WISE) band in units of magnitudes.
# 122  Brightness of the host star as measured using  the 3.6um (IRAC) band in units of magnitudes.
# 123  Brightness of the host star as measured using  the 4.5um (IRAC) band in units of magnitudes.
# 124  Brightness of the host star as measured using  the 5.8um (IRAC) band in units of magnitudes.
# 125  Brightness of the host star as measured using  the 8.0um (IRAC) band in units of magnitudes.
# 126  Brightness of the host star as measured using  the 24um (MIPS) band in units of magnitudes.
# 127  Brightness of the host star as measured using  the 70um (MIPS) band in units of magnitudes.
# 128  Brightness of the host star as measured using  the 160um (MIPS) band in units of magnitudes.
# 129  Brightness of the host star as measured  using the 12um (IRAS) band in units of Jy.
# 130  Brightness of the host star as measured  using the 25um (IRAS) band in units of Jy.
# 131  Brightness of the host star as measured  using the 60um (IRAS) band in units of Jy.
# 132  Brightness of the host star as measured  using the 100um (IRAS) band in units of Jy.
# 133  Number of photometry measurements available  for this star in the NASA Exoplanet Archive.
# 135  Color of the star as measured by the  difference between U and B (Johnson) bands.
# 136  Color of the star as measured by the  difference between B and V (Johnson) bands.
# 137  Color of the star as measured by the difference  between V (Johnson) and I (Cousins) bands.
# 138  Color of the star as measured by the difference between V (Johnson) and R (Cousins) bands.
# 139  Color of the star as measured by the  difference between J and H (2MASS) bands.
# 140  Color of the star as measured by the  difference between H and K (2MASS) bands.
# 141  Color of the star as measured by the  difference between K and K (2MASS) bands.
# 142  Color of the star as measured by the difference  between b and y (Stromgren) bands.
# 143  Color of the star as measured by  the m1 (Stromgren) system.
# 144  Color of the star as measured  by the c1 (Stromgren) system.
# 145  Number of color measurements available  for this star in the NASA Exoplanet Archive.
# 147
#
# [143 rows x 3 columns]

# %%
df.to_html('NASAexoplanetsAttributesAndDefinition.html')

# %%
#here is a second solution
#array of pandasdataframes?
#try that

# %%
#here is a third
#what if we made 5 separate dataframes
#then appended them to a giant data frame

dfComb = pd.DataFrame(columns=["Database Column Name", "Table Label", "Description"])
dfDef = pd.DataFrame(columns=["Database Column Name", "Table Label", "Description"])
dfPl  = pd.DataFrame(columns=["Database Column Name", "Table Label", "Description"])
dfSt  = pd.DataFrame(columns=["Database Column Name", "Table Label", "Description"])
dfPho = pd.DataFrame(columns=["Database Column Name", "Table Label", "Description"])
dfClr = pd.DataFrame(columns=["Database Column Name", "Table Label", "Description"])

countUp = 0
for p in range(1, len(tables[0])):
    dfDef.loc[countUp] = [tables[0][p][0].encode('ascii', 'ignore').decode('ascii')] + [tables[0][p][1]] + [tables[0][p][2]]
    countUp += 1

countUp = 0
for p in range(1, len(tables[1])):
    dfPl.loc[countUp] = [tables[1][p][0].encode('ascii', 'ignore').decode('ascii')] + [tables[1][p][1]] + [tables[1][p][2]]
    countUp += 1
    
countUp = 0
for p in range(1, len(tables[2])):
    dfSt.loc[countUp] = [tables[2][p][0].encode('ascii', 'ignore').decode('ascii')] + [tables[2][p][1]] + [tables[2][p][2]]
    countUp += 1
    
countUp = 0
for p in range(1, len(tables[3])):
    dfPho.loc[countUp] = [tables[3][p][0].encode('ascii', 'ignore').decode('ascii')] + [tables[3][p][1]] + [tables[3][p][2]]
    countUp += 1

countUp = 0
for p in range(1, len(tables[4])):
    dfClr.loc[countUp] = [tables[4][p][0].encode('ascii', 'ignore').decode('ascii')] + [tables[3][p][1]] + [tables[4][p][2]]
    countUp += 1

# %%
print(len(dfDef))
print(len(dfPl))
print(len(dfSt))
print(len(dfPho))
print(len(dfClr))

lens = [32,40,35,24,11]

sum(lens)
# Out:
# 32
# 40
# 35
# 24
# 11
# 142

# %%
dfComb.append(dfDef , ignore_index = True)
dfComb
# Out:
# Empty DataFrame
# Columns: [Database Column Name, Table Label, Description]
# Index: []

# %%
# %%html
#
# <p>Definitions of Kepler Confirmed Exoplanet Parameters.</p>
#
#
# <table style="width:100%">
#   <tr>
#     <th>Numver</th>
#     <th>Database Column Name</th>
#     <th>Table Label</th>
#     <th>Description</th>
#   </tr>
#
#
# </table>
#
# <p>This is a suitable problem for machine learning algorithms to tackle.</p>
# Out:
# <p>Definitions of Kepler Confirmed Exoplanet Parameters.</p>
#
#
# <table style="width:100%">
#   <tr>
#     <th>Numver</th>
#     <th>Database Column Name</th>
#     <th>Table Label</th>
#     <th>Description</th>
#   </tr>
#
#
# </table>
#
# <p>This is a suitable problem for machine learning algorithms to tackle.</p>
